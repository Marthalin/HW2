# %% [markdown]
# Visit https://www.indeed.com/Top-Rated-Workplaces, and search for Data Scientist in Los Angeles. Scrape 50 company reviews of the first 50 companies (if fewer than 50, just get the companies names on the first page). Retrieve the company’s name, title of the reviewer, the date of the review, the title, rating, review content, pros, and cons and the review. The output can to be shown in the form of a table. If any of the companies doesn’t have 50 reviews, then you just need to get whatever it has on the website.

# %%
from bs4 import BeautifulSoup
import urllib
import re
import pandas as pd
import requests
from urllib.request import urlopen

# %%
company = []
reviewer = []
date = []
title = []
rating = []
content = []
pros = []
cons = []
url = "https://www.indeed.com/cmp?q=Data+Scientist&l=Los+Angeles%2C+CA&from=discovery-cmp-search"

page = urlopen(url)
soup = BeautifulSoup(page, 'lxml')
all_matches = soup.findAll(attrs = {'data-tn-element':['reviews-footer-link']})

for review in all_matches:
    for i in range(3):
        review_url = "https://www.indeed.com" + review['href']
        review_page = urlopen(review_url)
        review_soup = BeautifulSoup(review_page, 'lxml')
        review_container = review_soup.findAll(attrs = {'class':['cmp-review-container']})

        for each in review_container:
            #company name
            company_name = review_soup.findAll(attrs = {'class':['cmp-company-name']})
            company.append(company_name[0].text)
            #review title
            review_title = each.findAll('div', attrs = {'class':['cmp-review-title']})
            title.append(review_title[0].text)
            #rating
            review_rating = each.findAll(attrs = {'class':['cmp-ratingNumber']})
            rating.append(review_rating[0].text)
            #review content
            review_content = each.findAll(attrs = {'class':['cmp-review-text']})
            content.append(review_content[0].text)
            #date
            review_date = each.findAll(attrs = {'class':['cmp-review-date-created']})
            date.append(review_date[0].text)
            #title of reviewer
            review_reviewer = each.findAll(attrs = {'class':['cmp-reviewer']}) 
            reviewer.append(review_reviewer[0].text)

            #Pros
            if not each.findAll(attrs = {'class':['cmp-review-pros']}):
                pros.append('N/A')
            else:
                review_pros = each.findAll(attrs = {'class':['cmp-review-pros']})
                pros.append(review_pros[0].text)

            #Cons
            if not each.findAll(attrs = {'class':['cmp-review-cons']}):
                cons.append('N/A')
            else:
                review_cons = each.findAll(attrs = {'class':['cmp-review-cons']})
                cons.append(review_cons[0].text)

            ## Change the pages to Next Page
            if not review_soup.findAll(attrs={'data-tn-element':['next-page']}):
                break
            else:
                review_url_all = review_soup.findAll(attrs={'data-tn-element':['next-page']})
                review_url = 'http://www.indeed.com/'+ str(review_url_all[0]['href'])

# %%
cmp = {'Company' : company, 
           'Reviewer' : reviewer,
           'Date' : date,
           'Review Title' : title, 
           'Rating' : rating, 
           'Review content' : content,   
           'Pros' : pros, 
           'Cons' : cons}

df = pd.DataFrame.from_dict(cmp)

# %%
df
# Out:
#                   Company                                    Reviewer  \
# 0                Veritone        Hopefully not randomly laid-off soon
# 1                    Hulu                  Viewer Experience Advocate
# 2                Veritone        Hopefully not randomly laid-off soon
# 3                    Hulu                  Viewer Experience Advocate
# 4                    Hulu                         Marketing/Sales Ops
# 12         July 28, 2019       Working in Broadcast Operations is Enjoyable
# 13         July 26, 2019                                        Place sucks
# 14         June 15, 2019                               Proceed with caution
# 15         June 14, 2019                                Great place to work
# 16          May 18, 2019                       Productive fun place to work
# 17          May 16, 2019                Management and this place is a joke
# 18        March 25, 2019                               Hulu is the greatest
# 19        March 14, 2019                   Fun work place, productive, etc.
# 20        March 12, 2019                      Excellent company to work for
# 21     February 28, 2019                              Its is not a hard job
# 22      February 2, 2019                                                n/a
# 23      January 29, 2019         Great Company, Not so great office culture
# 24      October 25, 2019                                          It's okay
# 25      October 19, 2019  Was a model of a new kind of company but is no...
# 26       October 4, 2019                             Amazing Place to Work!
# 27       October 1, 2019  Environment filled with perks and fun, but not...
# 28    September 28, 2019                                 Can’t have a life.
# 29    September 25, 2019          Innovative and stimulating place to work.
# ...                  ...                                                ...
# 1650    October 13, 2019                                           Horrible
# 1651    October 12, 2019            It is a good place to learn new things.
# 1652    October 10, 2019             Productive and Hassle-free environment
# 1653     October 9, 2019                         The ability to work remote
# 1654     October 8, 2019                                    Poor management
# 1655     October 8, 2019                               Good and Progressive
# 1656  September 10, 2019                                                 Ok
# 1657    October 29, 2019                            Management was not good
# 1658    October 28, 2019                             A Good company to work
# 1659    October 28, 2019       Good company to learn with good job securtiy
# 1660    October 26, 2019                                     Dont work here
# 1661    October 24, 2019                  depends on account and management
# 1662    October 22, 2019                   Great for starting the IT career
# 1663    October 21, 2019  Processes & company culture make it difficult ...
# 1664    October 21, 2019                                  Work life balance
# 1665    October 20, 2019                                            InfoSys
# 1666    October 18, 2019                                    Good experience
# 1667    October 17, 2019                                   Slow Growth rate
# 1668    October 15, 2019             Productive and very good place to work
# 1669    October 14, 2019                                            Average
# 1670    October 14, 2019        Poor company for advancement and inclusion.
# 1671    October 13, 2019                                           Horrible
# 1672    October 12, 2019            It is a good place to learn new things.
# 1673    October 10, 2019             Productive and Hassle-free environment
# 1674     October 9, 2019                         The ability to work remote
# 1675     October 8, 2019                                    Poor management
# 1676     October 8, 2019                               Good and Progressive
# 1677       June 11, 2019                               Fun work environment
# 1678       June 11, 2019                               Fun work environment
# 1679       June 11, 2019                               Fun work environment
#
#      Rating                                     Review content  \
# 0       3.0  Too many parts moving at the same time with un...
# 1       3.0  I loved working here in the beginning. Once th...
# 2       3.0  Too many parts moving at the same time with un...
# 3       3.0  I loved working here in the beginning. Once th...
# 4       3.0  In the beginning Hulu was a passion project ca...
# 5       5.0  Amazing place to work. Fast paced and interest...
# 6       4.0  Working at Hulu feels like living on a college...
# 7       5.0  Don’t have kids, or go to school with this com...
# 8       5.0  Hulu is an incredible place to be employed.  A...
# 9       5.0  Best place to work in LA for a few years runni...
# 10      1.0  When you first start it's awesome. Then once y...
# 11      4.0  you could wear most of the clothing without be...
# 12      4.0  I performed my work as well as I could, and co...
# 13      1.0  Was let go even though I was hitying all the s...
# 19                 ProsGood pay, decent hours, easy job
# 20                                                  N/A
# 21                ProsMany benefits and pretty okay pay
# 22                                                  N/A
# 23    ProsFree Hulu, Free coffee, $10 weekly snack s...
# 24                                                  N/A
# 25    Prosreally work hard to keep things fun, holid...
# 26                                                  N/A
# 27               ProsA lot of free food, good insurance
# 28                                                  N/A
# 29                                         ProsBenefits
# ...                                                 ...
# 1650                                                N/A
# 1651                                                N/A
# 1652                                                N/A
# 1653                                                N/A
# 1654                                                N/A
# 1655                                                N/A
# 1656                                                N/A
# 1657  ProsHardly ever anyone supervising you so you ...
# 1658                                                N/A
# 1659                                                N/A
# 1660                                 ProsGreat benefits
# 1661                                                N/A
# 1662                                                N/A
# 1663                                                N/A
# 1664                                                N/A
# 1665                    ProsFind places for you to work
# 1666                                                N/A
# 1667                                                N/A
# 1668                                                N/A
# 1669                                                N/A
# 1670                                                N/A
# 1671                                                N/A
# 1672                                                N/A
# 1673                                                N/A
# 1674                                                N/A
# 1675                                                N/A
# 1676                                                N/A
# 1677                                                N/A
# 1678                                                N/A
# 1679                                                N/A
#
#                                                    Cons
# 0                       ConsRandom unexplained lay-offs
# 1                                                   N/A
# 2                       ConsRandom unexplained lay-offs
# 3                                                   N/A
# 4     Consmanagers from old world media, turned corp...
# 5                                                   N/A
# 6     ConsA lot of work with little advancement and ...
# 7                                                   N/A
# 8     ConsSalary is less than other places of equiva...
# 9                                                   N/A
# 10                                                  N/A
# 11                                                  N/A
# 12                                                  N/A
# 13                                       ConsEverything
# 14                                                  N/A
# 15                                                  N/A
# 16                   ConsLocation for me, hotel seating
# 17                                 ConsWhere do I start
# 18                                                  N/A
# 19         ConsNot very organized with schedules/shifts
# 20                                                  N/A
# 21    ConsVery poor communication and transparency a...
# 22                                                  N/A
# 23    ConsNot enough transparency. Not many opportun...
# 24                                                  N/A
# 25    Consmanagers from old world media, turned corp...
# 26                                                  N/A
# 27    ConsA lot of work with little advancement and ...
# 28                                                  N/A
# 29    ConsSalary is less than other places of equiva...
# ...                                                 ...
# 1650                                                N/A
# 1651                                                N/A
# 1652                                                N/A
# 1653                                                N/A
# 1654                                                N/A
# 1655                                                N/A
# 1656                                                N/A
# 1657  ConsNowhere to go and no one to go to when the...
# 1658                                                N/A
# 1659                                                N/A
# 1660                                   ConsLow pay rate
# 1661                                                N/A
# 1662                                                N/A
# 1663                                                N/A
# 1664                                                N/A
# 1665                      Constraining and expectations
# 1666                                                N/A
# 1667                                                N/A
# 1668                                                N/A
# 1669                                                N/A
# 1670                                                N/A
# 1671                                                N/A
# 1672                                                N/A
# 1673                                                N/A
# 1674                                                N/A
# 1675                                                N/A
# 1676                                                N/A
# 1677                                                N/A
# 1678                                                N/A
# 1679                                                N/A
#
# [1680 rows x 8 columns]

# %%
len(company)
len(title)
len(date)
len(content)
len(reviewer)
len(pros)
# Out:
# 1680
